# %%
import pandas as pd
import numpy  as np
import psycopg2 as ps
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from matplotlib import pyplot as plt

# The following two lines are not mandatory for the code to work
import matplotlib.style as style

# %%
df=pd.read_csv('/content/test2_2.csv')
df
# Out:
#          Time (s)  ...  Absolute acceleration (m/s^2)
# 0       12.330311  ...                       0.672945
# 1       12.340279  ...                       1.180881
# 2       12.350247  ...                       1.391400
# 3       12.360214  ...                       1.519167
# 4       12.370182  ...                       1.902170
# ...           ...  ...                            ...
# 12856  140.479790  ...                       9.131452
# 12857  140.489759  ...                       9.116804
# 12858  140.499727  ...                       9.208004
# 12859  140.509695  ...                       9.266985
# 12860  140.519663  ...                       9.418244
#
# [12861 rows x 5 columns]

# %% [markdown]
# # **Plot Style 1**

# %%
style.use('dark_background') #this turns the background area of the chart to dark

plt.rcParams["figure.figsize"] = [15, 10]#Scales the size of the chart
fig, ax1 = plt.subplots()# Generates the chart area

ax1.plot(figsize=(10,5))
ax1.title.set_text('Acceleration vs Time')#Chart Title
ax1.plot(x, y1, 'g-',)# plots the data points of a selected data set
ax1.set_xlabel("Time (s)")#Labels x-axis
ax1.set_ylabel("Absolute acceleration (m/s^2)")#Labels y-axis
# Out:
# Text(0, 0.5, 'Absolute acceleration (m/s^2)')

# %% [markdown]
# # **Plot Style 2**

# %%
style.use('dark_background') #this turns the background area of the chart to dark

plt.rcParams["figure.figsize"] = [15, 10]#Scales the size of the chart
fig, ax1 = plt.subplots()# Generates the chart area

ax1.plot(figsize=(10,5))
ax1.title.set_text('Acceleration vs Time')#Chart Title
ax1.plot(x, y1, 'g-',)# plots the data points of a selected data set
ax1.set_xlabel("Time (s)")#Labels x-axis
ax1.set_ylabel("Absolute acceleration (m/s^2)")#Labels y-axis
ax1.xaxis.grid(True, which='minor', linestyle='-', linewidth=0.25)
ax1.grid()# adds gridliness

# %% [markdown]
# # **Plot Style 3**

# %%
style.use('dark_background') #this turns the background area of the chart to dark

plt.rcParams["figure.figsize"] = [15, 10]#Scales the size of the chart
fig, ax1 = plt.subplots()# Generates the chart area

ax1.plot(figsize=(10,5))
ax1.title.set_text('Acceleration vs Time')#Chart Title
ax1.plot(x, y1, 'g-',)# plots the data points of a selected data set
ax1.set_xlabel("Time (s)")#Labels x-axis
ax1.set_ylabel("Absolute acceleration (m/s^2)")#Labels y-axis

# Don't allow the axis to be on top of your data
ax1.set_axisbelow(True)

# Turn on the minor TICKS, which are required for the minor GRID
ax1.minorticks_on()

# Customize the major grid
ax1.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
ax1.grid(which='minor', linestyle=':', linewidth='0.5', color='black')

# Turn off the display of all ticks.
ax1.tick_params(which='both', # Options for both major and minor ticks
                top='off', # turn off top ticks
                left='off', # turn off left ticks
                right='off',  # turn off right ticks
                bottom='off') # turn off bottom ticks

# %% [markdown]
# # **Plot Style 4**

# %%
df.plot()# Plots everything in the data set

plt.rcParams["figure.figsize"] = [15, 10]#Scales the size of the chart
x = df['Time (s)']# Places selected column of the data set on the x-axis
y1 = df['Absolute acceleration (m/s^2)'] #Places selected column of the data set on the x-axis
